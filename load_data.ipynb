# %%
import pandas as pd
from config.config import OUTPUT_FILE, OUTPUT_CSV_FILE

df = pd.read_json(OUTPUT_FILE)
df

df.to_csv(OUTPUT_CSV_FILE)
df
# Out:
#     item_id  amount currency     Şəhər       Marka                   Model  \
# 0   9475914   20700      USD      Bakı     Changan                   Uni-Z
# 1   9484809   17400      AZN      Bakı        Ford  Fusion (North America)
# 2   8962955   19500      AZN      Bakı  Volkswagen                Scirocco
# 3   9479629   31500      USD      Bakı     Changan              Deepal S09
# 4   9477675   17700      AZN  Sumqayıt        Ford                    Kuga
# 5   9459989   27500      AZN  Sumqayıt         Kia                Sportage
# 6   9483665   37000      AZN      Bakı      Toyota             Yaris Cross
# 7   9410138   21900      AZN      Bakı     Hyundai                 Elantra
# 8   9437839   22900      AZN      Bakı     Hyundai                 Elantra
# 9   9514140   54000      AZN      Bakı      Scania                    R420
# 10  9514137   11500      AZN    Göyçay         BMW                     530
# 11  9513319   14000      AZN      Bakı      Nissan                    Note
# 12  9055483   39500      USD      Bakı    Mercedes                 CLA 200
# 13  8977140   36500      USD      Bakı       Lexus                  LX 570
# 14  9403912   18900      AZN      Bakı      Toyota                   Camry
# 15  9316501   12600      AZN  Sumqayıt   Chevrolet                   Cruze
# 16  9480119   24800      AZN  Sumqayıt      Nissan              Pathfinder
# 17  9442779   44700      AZN     Gəncə      Toyota      Land Cruiser Prado
# 18  9493572   24500      AZN  Sumqayıt     Hyundai                    ix35
# 19  9495617   18300      AZN      Bakı     Hyundai                 Elantra
# 20  9315607   32500      AZN      Bakı         Kia                 Sorento
# 21  9478943   21500      AZN  Sumqayıt     Hyundai                  Avante
# 22  9467401    9500      AZN      Bakı     Hyundai                    Getz
# 23  9514138   22500      AZN      Bakı         BMW                     328
# 24  9474846   30500      AZN      Bakı     Hyundai                Santa Fe
# 25  9350637   31600      AZN      Bakı  Land Rover         Discovery Sport
# 26  9497122   65500      AZN      Bakı  Mitsubishi            Pajero Sport
# 27  9315428   19900      AZN      Bakı   Chevrolet                  Malibu
# 28  9165427   23500      USD      Bakı   Chevrolet                  Camaro
# 29  9304577   21800      AZN      Bakı     Hyundai                 Elantra
# 30  9514142    8500      AZN      Bakı       Mazda                       6
# 31  9372756   49900      USD      Bakı       ZEEKR                     Mix
# 32  9427264   10900      AZN      Bakı       Ravon                Nexia R3
# 33  9512985   38500      USD      Bakı      Toyota                  Avalon
# 34  9204187  110000      USD      Bakı        Ford                   F-150
# 35  8948342   43900      USD      Bakı  Land Rover             Range Rover
#
#     Buraxılış ili                 Ban növü        Rəng  \
# 0            2025  Offroader / SUV, 5 qapı         Boz
# 1            2016                    Sedan         Göy
# 2            2010          Hetçbek, 3 qapı        Qara
# 3            2025  Offroader / SUV, 5 qapı         Göy
# 4            2013  Offroader / SUV, 5 qapı          Ağ
# 5            2014  Offroader / SUV, 5 qapı          Ağ
# 6            2023  Offroader / SUV, 5 qapı      Qızılı
# 7            2018                    Sedan        Qara
# 8            2018                    Sedan        Qara
# 9            2012                   Dartqı          Ağ
# 10           2002                    Sedan          Ağ
# 11           2016          Hetçbek, 5 qapı          Ağ
# 12           2019                    Sedan          Ağ
# 13           2012  Offroader / SUV, 5 qapı          Ağ
# 14           2010                    Sedan        Qara
# 15           2013                    Sedan          Ağ
# 16           2012  Offroader / SUV, 5 qapı        Qara
# 17           2013  Offroader / SUV, 5 qapı          Ağ
# 18           2014  Offroader / SUV, 5 qapı          Ağ
# 19           2012                    Sedan         Boz
# 20           2015  Offroader / SUV, 5 qapı          Ağ
# 21           2015                    Sedan         Göy
# 22           2007          Hetçbek, 5 qapı     Qəhvəyi
# 23           2013                    Sedan        Qara
# 24           2017  Offroader / SUV, 5 qapı        Mavi
# 25           2017  Offroader / SUV, 5 qapı          Ağ
# 26           2023  Offroader / SUV, 5 qapı  Yaş Asfalt
# 27           2018                    Sedan          Ağ
# 28           2013                     Kupe        Qara
# 29           2016                    Sedan         Göy
# 30           2003                    Sedan          Ağ
# 31           2025                  Minivan          Ağ
# 32           2017                    Sedan          Ağ
# 33           2025                    Sedan        Qara
# 34           2021      Pikap, ikiqat kabin         Boz
# 35           2016  Offroader / SUV, 5 qapı        Qara
#
#                              Mühərrik         Yürüş
# 0   1.5 L / 215 a.g. / Plug-in Hibrid          0 km
# 1           1.5 L / 181 a.g. / Benzin    223 699 km
# 2           1.4 L / 160 a.g. / Benzin    204 000 km
# 3   1.5 L / 318 a.g. / Plug-in Hibrid          0 km
# 4           1.6 L / 150 a.g. / Benzin    258 470 km
# 5            2.0 L / 184 a.g. / Dizel    203 870 km
# 6           1.5 L / 120 a.g. / Benzin     20 000 km
# 7           2.0 L / 150 a.g. / Benzin    108 000 km
# 8           2.0 L / 200 a.g. / Benzin    167 000 km
# 9             12 L / 420 a.g. / Dizel  1 098 000 km
# 10          3.0 L / 231 a.g. / Benzin    250 000 km
# 11           1.2 L / 98 a.g. / Benzin     80 586 km
# 12          1.4 L / 163 a.g. / Benzin     26 000 km
# 13          5.7 L / 383 a.g. / Benzin    170 000 km
# 14          2.5 L / 179 a.g. / Benzin    197 000 km
# 15          1.4 L / 140 a.g. / Benzin    221 000 km
# 16          3.5 L / 249 a.g. / Benzin    281 915 km
# 17          2.7 L / 163 a.g. / Benzin     53 000 km
# 18          2.4 L / 178 a.g. / Benzin    252 080 km
# 19          1.8 L / 150 a.g. / Benzin    180 000 km
# 20           2.0 L / 184 a.g. / Dizel    212 001 km
# 21           1.6 L / 136 a.g. / Dizel    176 214 km
# 22           1.4 L / 97 a.g. / Benzin    216 000 km
# 23          2.0 L / 245 a.g. / Benzin    230 000 km
# 24          2.0 L / 240 a.g. / Benzin     68 500 km
# 25          2.0 L / 240 a.g. / Benzin    125 000 km
# 26           2.4 L / 181 a.g. / Dizel     63 000 km
# 27          1.5 L / 160 a.g. / Benzin    213 000 km
# 28          6.2 L / 405 a.g. / Benzin    181 000 km
# 29          2.0 L / 150 a.g. / Benzin    137 000 km
# 30          2.0 L / 145 a.g. / Benzin    354 765 km
# 31                 422 a.g. / Elektro          0 km
# 32          1.5 L / 107 a.g. / Benzin    247 200 km
# 33          2.0 L / 197 a.g. / Hibrid          0 km
# 34          3.5 L / 375 a.g. / Benzin     11 650 km
# 35          3.0 L / 360 a.g. / Benzin    115 000 km
