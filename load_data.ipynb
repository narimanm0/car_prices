# %%
import pandas as pd
from config.config import OUTPUT_FILE, OUTPUT_CSV_FILE

df = pd.read_json(OUTPUT_FILE)
df

df.to_csv(OUTPUT_CSV_FILE)
df
# Out:
#       item_id  amount currency   Şəhər       Marka                   Model  \
# 0     9484384   17500      AZN    Bakı     Hyundai                  Sonata
# 1     9510860   27300      AZN    Bakı      Toyota                 Corolla
# 2     9351100   32123      AZN    Bakı      Toyota                 Corolla
# 3     9484758   17500      AZN   Qazax   Chevrolet                    Trax
# 4     9441324   24900      AZN    Bakı        Ford  Fusion (North America)
# ...       ...     ...      ...     ...         ...                     ...
# 3060  9460150   18800      AZN    Bakı        Ford                 Transit
# 3061  9492069   36000      AZN    Bakı  Volkswagen                 Touareg
# 3062  9506192   14800      AZN    Bakı      Nissan                   March
# 3063  8975635   12500      AZN    Bakı     Hyundai                     i30
# 3064  9517279   11500      AZN  Şirvan  Volkswagen                  Passat
#
#       Buraxılış ili                 Ban növü          Rəng  \
# ...
